# %% [markdown]
# <hr style="border: none; border-top: 2px solid #FFFFFF; margin: 20px 0;">

# %% [markdown]
# <h2 style="color: #1E90FF; text-align: center; font-size: 28px; font-family: 'Helvetica Neue', Arial, sans-serif; font-weight: bold; margin-bottom: 30px; letter-spacing: 1px;">
#     <span style="font-size: 32px; text-transform: uppercase;">Acessibilidade urbana e desigualdades espaciais:</span><br>
#     <span style="font-size: 36px; color: #ff6347; text-transform: uppercase;">uma análise com ciência de dados e inteligência artificial explicável </span><br>
#     <span style="font-size: 24px; font-weight: normal; color: #555; text-transform: none;">no GEOinsightLab</span>
# </h2>

# %% [markdown]
# <hr style="border: none; border-top: 2px solid #FFFFFF; margin: 20px 0;">

# %% [markdown]
# <div style="background-color: #2E3B4E; color: #FFFFFF; padding: 15px; border-left: 5px solid #FFA500; font-family: Arial, sans-serif;">
#     <h2 style="background-color: #FFA500; padding: 10px; color: #FFFFFF; text-align: center; margin: 0;"> Estrutura da Análise: </h2>
#     <ul style="list-style-type: none; padding-left: 20px; margin-top: 10px; margin-bottom: 10px;">
#         <li>1. Realizar uma análise exploratória de dados espaciais</li>
#         <li>2. Aplicar algoritmos de agrupamento (K-Means, GMM e Agglomerative)</li>
#         <li>3. Explicar os agrupamentos com recurso a métodos de inteligência artificial explicável</li>
#         <li>4. Integrar o conceito da cidade dos 15 minutos na análise de acessibilidade pedonal</li>
#         <li>5. Utilizar modelos supervisionados para o cálculo da atratividade e a definição do peso das variáveis, com recurso a PCA e AFC</li>
#         <li>6. Implementar o modelo preditivo XGBoost para estimar a atratividade dos edifícios </li>
#         <li>7. Interpretar os resultados do modelo preditivo com métodos de inteligência artificial explicável, promovendo a transparência analítica</li>
#         <li>8. Conclusões (<i>insights</i>)</li>
#     </ul>
# </div>
#
# <hr style="border: none; border-top: 2px solid #FFFFFF; margin: 20px 0;">
#
# <div style="background-color: #2E3B4E; color: #FFFFFF; padding: 15px; border-left: 5px solid #FFA500; font-family: Arial, sans-serif;">
#     <b>Objetivos:</b>
#     <ol style="padding-left: 20px; margin-top: 10px; margin-bottom: 10px;">
#         <li><b>Identificar</b> padrões espaciais de acessibilidade a serviços essenciais, com base na análise de dados abertos e georreferenciados</li>
#         <li><b>Aplicar</b> algoritmos de ciência de dados e técnicas de inteligência artificial explicável para compreender os fatores que condicionam o acesso da população aos serviços</li>
#         <li><b>Desenvolver</b> visualizações interativas e acessíveis que apoiem a interpretação dos resultados e a transparência das decisões algorítmicas na plataforma GEOInsightLab</li>
#         <li><b>Avaliar</b> os impactos das desigualdades territoriais na acessibilidade urbana, considerando a distribuição dos serviços e os perfis sociodemográficos da população</li>
#     </ol>
#     <br>
#    <p><b>Questões de Partida:</b></p>
# <ol>
#   <li>Que padrões espaciais de acessibilidade a serviços essenciais podem ser identificados no município do Porto através da análise de dados georreferenciados?</li>
#   <li>De que forma a ciência de dados e a inteligência artificial explicável podem contribuir para a análise crítica e transparente da acessibilidade pedonal em meio urbano?</li>
# </ol>
# </div>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #FFFFFF; margin: 10px 0;">

# %% [markdown]
# <h2 style="color: #FFA07A;">1. Importação das bibliotecas</h2>

# %%
from IPython.display import Javascript, display
import time

def setup_toggle_button():
    js = """
    (function() {
        function ensureManagerExists() {
            if (!window.cellVisibilityManager) {
                window.cellVisibilityManager = {
                    toggleButton: null,

                    hideCells: function() {
                        try {
                            document.querySelectorAll('.jp-Cell, .cell').forEach(cell => {
                                let editor = cell.querySelector('.jp-InputArea-editor, .input_area');
                                if (editor && editor.innerText.includes('# hide-me')) {
                                    let input = cell.querySelector('.jp-InputArea, .input_area');
                                    if (input) {
                                        input.style.display = 'none';
                                        cell.classList.add('hidden');
                                    }
                                }
                            });
                        } catch (e) {
                            console.warn("Erro ao ocultar células:", e);
                        }
                    },

                    showCells: function() {
                        try {
                            document.querySelectorAll('.jp-Cell, .cell').forEach(cell => {
                                if (cell.classList.contains('hidden')) {
                                    let input = cell.querySelector('.jp-InputArea, .input_area');
                                    if (input) {
                                        input.style.display = '';
                                        cell.classList.remove('hidden');
                                    }
                                }
                            });
                        } catch (e) {
                            console.warn("Erro ao mostrar células:", e);
                        }
                    },

                    toggleCells: function() {
                        try {
                            let hiddenCells = document.querySelectorAll('.hidden');
                            if (hiddenCells.length > 0) {
                                this.showCells();
                                if (this.toggleButton) this.toggleButton.innerText = "Ocultar Código";
                            } else {
                                this.hideCells();
                                if (this.toggleButton) this.toggleButton.innerText = "Mostrar Código";
                            }
                        } catch (e) {
                            console.warn("Erro ao alternar células:", e);
                        }
                    }
                };
            }
        }

        function createToggleButton() {
            ensureManagerExists();

            if (!document.getElementById('toggleCodeButton')) {
                let btn = document.createElement('button');
                btn.innerText = "Mostrar Código";
                btn.id = "toggleCodeButton";
                btn.style.position = 'fixed';
                btn.style.top = '10px';
                btn.style.right = '10px';
                btn.style.padding = '10px 20px';
                btn.style.zIndex = '1000';
                btn.style.backgroundColor = '#007bff';
                btn.style.color = 'white';
                btn.style.border = 'none';
                btn.style.borderRadius = '5px';
                btn.style.cursor = 'pointer';
                btn.onclick = function() {
                    if (window.cellVisibilityManager) {
                        window.cellVisibilityManager.toggleCells();
                    }
                };

                document.body.appendChild(btn);
                window.cellVisibilityManager.toggleButton = btn;
            }
        }

        setTimeout(() => {
            try {
                ensureManagerExists();
                createToggleButton();
            } catch (e) {
                console.warn("Erro ao inicializar cellVisibilityManager:", e);
            }
        }, 3000);

        if (!window.cellVisibilityManager) {
            ensureManagerExists();
        }

        // Impedir rolagem automática para o final
        setTimeout(() => {
            if (window) {
                window.scrollTo({ top: 0, behavior: 'smooth' });
            }
        }, 500);
    })();
    """
    display(Javascript(js))

setup_toggle_button()

# hide-me
display(Javascript('window.cellVisibilityManager.hideCells();'))

# %% [markdown]
# <div style="background-color: #FFFFFF; color: #333333; padding: 15px; border-left: 5px solid #FFA500; font-family: Arial, sans-serif; text-align: justify;">
# <p><b style="color: #FFA500; font-size: 18px;">Contexto:</b></p> <p>Antes de avançar com o desenvolvimento da investigação, é fundamental assegurar que se dispõe das ferramentas adequadas para a sua implementação. Para esse efeito, procede-se à importação de um conjunto de bibliotecas que permitirá a execução das diversas tarefas previstas.</p>
#
# <b>O que é uma biblioteca em programação?</b> <br><br> 🔸 Em programação, uma biblioteca corresponde a um conjunto estruturado de funções, classes e rotinas que disponibilizam funcionalidades definidas para apoiar o desenvolvimento de <i>software</i>. Estas bibliotecas encapsulam algoritmos e soluções eficientes, o que possibilita a reutilização de código e reduz a necessidade de construção a partir do zero.<br><br> 🔸 São utilizadas em domínios como a manipulação de dados, visualização gráfica, inteligência artificial e computação científica. O seu uso contribui para um desenvolvimento mais célere, uma organização de código mais modular e uma manutenção simplificada dos projectos, promovendo a adopção de boas práticas.<br><br> 🔸 As bibliotecas estão agrupadas de acordo com as suas funções, o que permite uma configuração eficaz do ambiente de trabalho. Esta organização facilita a compreensão do seu propósito e garante o acesso a documentação estruturada.</p>
# <p><b>Execute e explore!</b></p>
# </div>

# %% [markdown]
# <div style="border: none; margin: 5px 0; border-top: 1px dashed #FFFFFF; border-bottom: 1px dashed #FFFFFF; height: 5px;"></div>

# %%
# ===================================================================
# Core Libraries for Data Manipulation
# ===================================================================
import os  
import pandas as pd  
import numpy as np  

# ===================================================================
# Libraries for Spatial Data Processing
# ===================================================================
import geopandas as gpd
import esda
import mapclassify
import fiona 
import libpysal as ps
from libpysal.weights import KNN, DistanceBand
from shapely.geometry import Point, Polygon
from shapely import wkt
from esda.moran import Moran

# ===================================================================
# Libraries for Data Visualization
# ===================================================================
import matplotlib.pyplot as plt  
import seaborn as sns  
import plotly.express as px
import plotly.graph_objects as go
import folium
from folium import Element
from folium.plugins import MeasureControl, MiniMap, MousePosition
from branca.colormap import linear
from plotly.subplots import make_subplots

# ===================================================================
# Libraries for Machine Learning and Clustering
# ===================================================================
from sklearn.cluster import KMeans, AgglomerativeClustering  
from sklearn.mixture import GaussianMixture  
from sklearn.metrics import silhouette_score, calinski_harabasz_score 
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import StandardScaler  
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingRegressor  
from sklearn.decomposition import PCA

# ===================================================================
# Libraries for Regression Models and Optimization
# ===================================================================
import statsmodels.api as sm  
import statsmodels.formula.api as smf  
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet  
from sklearn.svm import SVR  
from xgboost import XGBRegressor, XGBClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from statsmodels.stats.multicomp import pairwise_tukeyhsd  

# ===================================================================
# Libraries for Model Selection and Optimization
# ===================================================================
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score  

# ===================================================================
# Libraries for Model Evaluation Metrics
# ===================================================================
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score,
    davies_bouldin_score, accuracy_score, classification_report, confusion_matrix
)

# ===================================================================
# Libraries for Model Explainability
# ===================================================================
from lime.lime_tabular import LimeTabularExplainer  
import shap 

# ===================================================================
# Libraries for Structural Equation Modeling
# ===================================================================
from semopy import Model, calc_stats

# ===================================================================
# Libraries for Building Interactive Dashboards
# ===================================================================
import dash  
from dash import dcc, html, Input, Output, State, Dash
from dash import dash_table

# ===================================================================
# Libraries for Port and Socket Management
# ===================================================================
import socket  
import random  

# ===================================================================
# Libraries for JSON File Handling
# ===================================================================
import json  

# ===================================================================
# Libraries for Jupyter Notebook Interaction
# ===================================================================
from IPython.display import Javascript, display, HTML, clear_output
from IPython import get_ipython  

# ===================================================================
# Libraries for Object Serialization and Complex Structures
# ===================================================================
import dill  
import pickle  

# ===================================================================
# Libraries for System and Directory Management
# ===================================================================
import sys  
from contextlib import redirect_stdout, redirect_stderr  

# ===================================================================
# Libraries for Image and Graphics Handling
# ===================================================================
import io
from io import BytesIO  
import base64  

# ===================================================================
# Libraries for Subprocess Execution and Temporary Files
# ===================================================================
import subprocess
from tempfile import NamedTemporaryFile

# ===================================================================
# Libraries for Interactive Widgets in Jupyter Notebook
# ===================================================================
import ipywidgets as widgets  
from ipywidgets import interact  

# ===================================================================
# Libraries for Custom Color Mapping in Plots
# ===================================================================
from matplotlib.colors import ListedColormap  

# ===================================================================
# Libraries for Table Formatting and Output Display
# ===================================================================
from tabulate import tabulate
from rich.console import Console  
from rich.table import Table  

# ===================================================================
# Library for Progress Bars in Long Loops
# ===================================================================
from tqdm import tqdm  

# ===================================================================
# Libraries for Time Handling
# ===================================================================
import time

# %% [markdown]
# <div style="border: none; margin: 5px 0; border-top: 1px dashed #FFFFFF; border-bottom: 1px dashed #FFFFFF; height: 5px;"></div>

# %% [markdown]
# Seguinte: [Análise exploratória de dados](clustering.ipynb)

# %% [markdown]
# <div style="border: none; margin: 5px 0; border-top: 1px dashed #FFFFFF; border-bottom: 1px dashed #FFFFFF; height: 5px;"></div>
